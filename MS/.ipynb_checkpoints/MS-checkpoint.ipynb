# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import LSTM, Dense
import matplotlib.pyplot as plt
import pandas
import numpy
import joblib

pandas.plotting.register_matplotlib_converters()
# Out:
# Using TensorFlow backend.

# %%
def graphicplotxy(x, y, x_label, y_label, title, filename):
    fig, ax = plt.subplots(figsize=(10,5))
    ax.plot(x, y, alpha=0.70, )
    
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.set_title(title)
    ax.legend(['MSE'])
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
    ax.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
    
    plt.show
    plt.savefig(filename)

def to_supervised(data, n_in, n_out):
    n_vars = 1
    df = pandas.DataFrame(data)
    cols, names = list(), list()
    # urutan waktu input ke t- (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
        
    # urutan waktu output ke t+ (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]          
    # concat
    agg = pandas.concat(cols, axis=1)
    agg.columns = names
    # drop baris yang bernilai Nan
    agg.dropna(inplace=True)
    val = agg.values
    X, y = val[:, 0:n_in], val[:, n_in:]
    X = X.reshape((X.shape[0], n_in, n_vars))
    return X, y

def eksperimen(nama, model, scaler, set_latih, set_uji, n_input = 1, n_neuron = 30, n_epoch = 40):
    n_feature = 1
    n_output = 1

    print("Hyperparameter {0}".format(nama))
    print("input = {0}\nneuron = {1}\nepoch = {2}".format(n_input, n_neuron, n_epoch))
    
    # sliding windows
    X_train, y_train = to_supervised(set_latih, n_input, n_feature)
    
    # Compile Model
    model.add(LSTM(n_neuron, input_shape=(n_input, n_feature)))
    model.add(Dense(n_output))
    model.compile(loss='mse', optimizer='adam')

    print("\nPelatihan {0} Mulai".format(nama))
    model.fit(X_train, y_train, epochs=n_epoch, verbose=0)
    model.save("{0}.h5".format(nama))
    print("Pelatihan {0} Selesai".format(nama))

    print("\nPengujian {0}".format(nama))
    X_test, y_test = to_supervised(set_uji, n_input, n_output)
    mse = model.evaluate(X_test, y_test)
    print("{0} MSE = {1}".format(nama, mse))

    print("\n-------------------------------------------------------------------------------------------\n")

# %%
#load data
set_latih = numpy.loadtxt('set_latih.csv', delimiter=",")
set_uji = numpy.loadtxt('set_uji.csv', delimiter=",")
scaler = joblib.load('scaler.gz')

# %%
# MS1
MS1 = Sequential()
eksperimen("MS1", MS1, scaler, set_latih, set_uji, n_input = 1, n_neuron = 30, n_epoch = 40)

# MS2
MS2 = Sequential()
eksperimen("MS2", MS2, scaler, set_latih, set_uji, n_input = 2, n_neuron = 30, n_epoch = 40)

# MS3
MS3 = Sequential()
eksperimen("MS3", MS3, scaler, set_latih, set_uji, n_input = 4, n_neuron = 30, n_epoch = 40)

# MS4
MS4 = Sequential()
eksperimen("MS4", MS4, scaler, set_latih, set_uji, n_input = 8, n_neuron = 30, n_epoch = 40)

# MS5
MS5 = Sequential()
eksperimen("MS5", MS5, scaler, set_latih, set_uji, n_input = 16, n_neuron = 30, n_epoch = 40)

# MS6
MS6 = Sequential()
eksperimen("MS6", MS6, scaler, set_latih, set_uji, n_input = 32, n_neuron = 30, n_epoch = 40)

# MS7
MS7 = Sequential()
eksperimen("MS7", MS7, scaler, set_latih, set_uji, n_input = 64, n_neuron = 30, n_epoch = 40)

# MS8
MS8 = Sequential()
eksperimen("MS8", MS8, scaler, set_latih, set_uji, n_input = 128, n_neuron = 30, n_epoch = 40)

# MS9
MS9 = Sequential()
eksperimen("MS9", MS9, scaler, set_latih, set_uji, n_input = 256, n_neuron = 30, n_epoch = 40)
# Out:
# Hyperparameter MS1
# input = 1
# neuron = 30
# epoch = 40
#
# Pelatihan MS1 Mulai
# Pelatihan MS1 Selesai
#
# Pengujian MS1
# 1088/1088 [==============================] - 0s 166us/step
# MS1 MSE = 0.06515064819113296
#
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MS2
# input = 2
# neuron = 30
# epoch = 40
#
# Pelatihan MS2 Mulai
# Pelatihan MS2 Selesai
#
# Pengujian MS2
# 1087/1087 [==============================] - 0s 67us/step
# MS2 MSE = 0.06333241935582916
#
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MS3
# input = 4
# neuron = 30
# epoch = 40
#
# Pelatihan MS3 Mulai
# Pelatihan MS3 Selesai
#
# Pengujian MS3
# 1085/1085 [==============================] - 0s 73us/step
# MS3 MSE = 0.06330571696505569
#
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MS4
# input = 8
# neuron = 30
# ...

# %%
mses = [round(0.06515064819113296, 6),
        round(0.06333241935582916, 6),
        round(0.06330571696505569, 6),
        round(0.06202897505970822, 6),
        round(0.06152368659797608, 6),
        round(0.06100660389114802, 6), 
        round(0.05975261590102824, 6),
        round(0.05757738082717162, 6), #BEST MS8
        round(0.059415473442833246, 6),
       ]
labels = ["MS1","MS2","MS3","MS4","MS5","MS6", "MS7", "MS8", "MS9"]
graphicplotxy(labels, mses, "model", "MSE", "Grafik MSE Model Satu Layer\nPenyetelan Input", "MS_Train_Input.png")
mses
# Out:
# [0.065151,
#  0.063332,
#  0.063306,
#  0.062029,
#  0.061524,
#  0.061007,
#  0.059753,
#  0.057577,
#  0.059415]

# %%
# MS11
MS11 = Sequential()
eksperimen("MS11", MS11, scaler, set_latih, set_uji, n_input = 128, n_neuron = 1, n_epoch = 40)

# MS12
MS12 = Sequential()
eksperimen("MS12", MS12, scaler, set_latih, set_uji, n_input = 128, n_neuron = 2, n_epoch = 40)

# MS13
MS13 = Sequential()
eksperimen("MS13", MS13, scaler, set_latih, set_uji, n_input = 128, n_neuron = 4, n_epoch = 40)

# MS14
MS14 = Sequential()
eksperimen("MS14", MS14, scaler, set_latih, set_uji, n_input = 128, n_neuron = 8, n_epoch = 40)

# MS15
MS15 = Sequential()
eksperimen("MS15", MS15, scaler, set_latih, set_uji, n_input = 128, n_neuron = 16, n_epoch = 40)

# MS16
MS16 = Sequential()
eksperimen("MS16", MS16, scaler, set_latih, set_uji, n_input = 128, n_neuron = 32, n_epoch = 40)

# MS17
MS17 = Sequential()
eksperimen("MS17", MS17, scaler, set_latih, set_uji, n_input = 128, n_neuron = 64, n_epoch = 40)

# MS18
MS18 = Sequential()
eksperimen("MS18", MS18, scaler, set_latih, set_uji, n_input = 128, n_neuron = 128, n_epoch = 40)

# MS19
MS19 = Sequential()
eksperimen("MS19", MS19, scaler, set_latih, set_uji, n_input = 128, n_neuron = +256, n_epoch = 40)
# Out:
# Hyperparameter MS11
# input = 128
# neuron = 1
# epoch = 40
#
# Pelatihan MS11 Mulai
# Pelatihan MS11 Selesai
#
# Pengujian MS11
# 961/961 [==============================] - 0s 343us/step
# MS11 MSE = 0.05935699460905871
#
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MS12
# input = 128
# neuron = 2
# epoch = 40
#
# Pelatihan MS12 Mulai
# Pelatihan MS12 Selesai
#
# Pengujian MS12
# 961/961 [==============================] - 0s 338us/step
# MS12 MSE = 0.05813378916663756
#
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MS13
# input = 128
# neuron = 4
# epoch = 40
#
# Pelatihan MS13 Mulai
# Pelatihan MS13 Selesai
#
# Pengujian MS13
# 961/961 [==============================] - 0s 338us/step
# MS13 MSE = 0.058305718144256544
#
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MS14
# input = 128
# ...

# %%
mses = [round(0.05935699460905871, 6),
        round(0.05813378916663756, 6),
        round(0.058305718144256544, 6),
        round(0.0575141553746674, 6),
        round(0.0578495381316645, 6),
        round(0.05757738082717162, 6), #MS8
        round(0.05760963586363534, 6), 
        round(0.05736134350144776, 6), #BEST MS17
        round(0.05843869734334524, 6),
        round(0.057743709111871135, 6),
       ]
labels = ["MS11","MS12","MS13","MS14","MS15","MS8","MS16", "MS17", "MS18", "MS19"]
graphicplotxy(labels, mses, "model", "MSE", "Grafik MSE Model Satu Layer\nPenyetelan Neuron", "MS_Train_Neuron.png")
mses
# Out:
# [0.059357,
#  0.058134,
#  0.058306,
#  0.057514,
#  0.05785,
#  0.057577,
#  0.05761,
#  0.057361,
#  0.058439,
#  0.057744]

# %%
# MS21
MS21 = Sequential()
eksperimen("MS21", MS21, scaler, set_latih, set_uji, n_input = 128, n_neuron = 64, n_epoch = 2)

# MS22
MS22 = Sequential()
eksperimen("MS22", MS22, scaler, set_latih, set_uji, n_input = 128, n_neuron = 64, n_epoch = 4)

# MS23
MS23 = Sequential()
eksperimen("MS23", MS23, scaler, set_latih, set_uji, n_input = 128, n_neuron = 64, n_epoch = 8)

# MS24
MS24 = Sequential()
eksperimen("MS24", MS24, scaler, set_latih, set_uji, n_input = 128, n_neuron = 64, n_epoch = 16)

# MS25
MS25 = Sequential()
eksperimen("MS25", MS25, scaler, set_latih, set_uji, n_input = 128, n_neuron = 64, n_epoch = 32)

# MS26
MS26 = Sequential()
eksperimen("MS26", MS26, scaler, set_latih, set_uji, n_input = 128, n_neuron = 64, n_epoch = 64)

# MS27
MS27 = Sequential()
eksperimen("MS27", MS27, scaler, set_latih, set_uji, n_input = 128, n_neuron = 64, n_epoch = 128)

# MS28
MS28 = Sequential()
eksperimen("MS28", MS28, scaler, set_latih, set_uji, n_input = 128, n_neuron = 64, n_epoch = 256)

# MS29
MS29 = Sequential()
eksperimen("MS29", MS29, scaler, set_latih, set_uji, n_input = 128, n_neuron = 64, n_epoch = 512)
# Out:
# Hyperparameter MS21
# input = 128
# neuron = 64
# epoch = 2
#
# Pelatihan MS21 Mulai
# Pelatihan MS21 Selesai
#
# Pengujian MS21
# 961/961 [==============================] - 1s 627us/step
# MS21 MSE = 0.061209288955851225
#
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MS22
# input = 128
# neuron = 64
# epoch = 4
#
# Pelatihan MS22 Mulai
# Pelatihan MS22 Selesai
#
# Pengujian MS22
# 961/961 [==============================] - 1s 620us/step
# MS22 MSE = 0.06151661038801896
#
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MS23
# input = 128
# neuron = 64
# epoch = 8
#
# Pelatihan MS23 Mulai
# Pelatihan MS23 Selesai
#
# Pengujian MS23
# 961/961 [==============================] - 1s 633us/step
# MS23 MSE = 0.057931084023026845
#
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MS24
# ...

# %%
mses = [round(0.061209288955851225, 6),
        round(0.06151661038801896, 6),
        round(0.057931084023026845, 6),
        round(0.05782703921958634, 6),
        round(0.05755291382213289, 6),
        round(0.05736134350144776, 6), #MS17 BEST
        round(0.058204751202020635, 6), 
        round(0.069166032362896, 6),
        round(0.1295951012363047, 6), 
        round(0.061832540196102036, 6),
       ]
labels = ["MS21","MS22","MS23","MS24","MS25","MS26","MS19", "MS27", "MS28", "MS29"]
graphicplotxy(labels, mses, "model", "MSE", "Grafik MSE Model Satu Layer\nPenyetelan Epoch", "MS_Train_Epoch.png")
mses
# Out:
# [0.061209,
#  0.061517,
#  0.057931,
#  0.057827,
#  0.057553,
#  0.057361,
#  0.058205,
#  0.069166,
#  0.129595,
#  0.061833]
