# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras import backend
import matplotlib.pyplot as plt
import pandas
import numpy
import joblib
import math
from datetime import datetime, timedelta

pandas.plotting.register_matplotlib_converters()

# %%
def graphicplotxy(x, y, x_label, y_label, title, filename):
    fig, ax = plt.subplots(figsize=(10,5))
    ax.plot(x, y, alpha=0.70, )
    
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.set_title(title)
    ax.legend(['MSE'])
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
    ax.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
    
    plt.show
    plt.savefig(filename)

def to_supervised(data, n_in, n_out):
    n_vars = 1
    df = pandas.DataFrame(data)
    cols, names = list(), list()
    # urutan waktu input ke t- (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
        
    # urutan waktu output ke t+ (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]          
    # concat
    agg = pandas.concat(cols, axis=1)
    agg.columns = names
    # drop baris yang bernilai Nan
    agg.dropna(inplace=True)
    val = agg.values
    X, y = val[:, 0:n_in], val[:, n_in:]
    #reshape(sample, timestep, feature/input)
    X = X.reshape((X.shape[0], 1, n_in))
    return X, y

def measure_rmse(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    return math.sqrt(mse)

def eksperimen(nama, scaler, set_latih, set_uji, n_input, n_neuron1, n_neuron2, n_epoch):
    n_timestep = 1
    n_output = 1
    
    print("Hyperparameter {0}".format(nama))
    print("input = {0}, neuron 1 = {1}, neuron 2 = {2}, epoch = {3}".format(n_input, n_neuron1, n_neuron2, n_epoch))
    
    X_train, y_train = to_supervised(set_latih, n_input, n_output)
    
    model = Sequential() # inisialisasi model
    model.add(LSTM(n_neuron1, input_shape=(n_timestep, n_input), return_sequences=True))
    model.add(LSTM(n_neuron2))
    model.add(Dense(n_output))
    model.compile(loss='mean_squared_error', optimizer='adam')

    model.fit(X_train, y_train, epochs=n_epoch, verbose=0)
    model.save("{0}.h5".format(nama))

    X_test, y_test = to_supervised(set_uji, n_input, n_output)
    
    saved_model = load_model('{0}.h5'.format(nama))
    y_pred = saved_model.predict(X_test, verbose=0)
    rmse = measure_rmse(y_test, y_pred)
    
    print("{0} RMSE = {1}".format(nama, rmse))
    print("-------------------------------------------------------------------------------------------\n")
    return rmse

# %%
#load data
set_latih = numpy.loadtxt('set_latih.csv', delimiter=",")
set_uji = numpy.loadtxt('set_uji.csv', delimiter=",")
scaler = joblib.load('scaler.gz')

# %%
# print('Eksperimen MD')

# window = [7,30,365]
# neuron = [64,128,256]
# neuron2 = [8,16,32]
# epoch = [50]
# md = pandas.DataFrame(columns=['nama','input','neuron1', 'neuron2', 'epoch','rmse', 'time (s)'])
# no=1
# for i in epoch:
#     for j in neuron2:
#         for k in neuron:
#             for l in window:
#                 nama = "MD{0}".format(no)
#                 start = datetime.now()
#                 rmse = eksperimen(nama, scaler, set_latih, set_uji, n_input = l, n_neuron1 = k, n_neuron2 = j, n_epoch = i)
#                 end = datetime.now()
#                 time = (end-start).total_seconds()
#                 md.loc[no] = [nama,l,k,j,i,rmse, time]
#                 md.to_csv('summary_md.csv')
#                 no += 1
# Out:
# Eksperimen MD
# Hyperparameter MD1
# input = 7, neuron 1 = 64, neuron 2 = 8, epoch = 50
# MD1 RMSE = 0.250664752442163
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD2
# input = 30, neuron 1 = 64, neuron 2 = 8, epoch = 50
# MD2 RMSE = 0.26444022729250954
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD3
# input = 365, neuron 1 = 64, neuron 2 = 8, epoch = 50
# MD3 RMSE = 0.28715961515027977
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD4
# input = 7, neuron 1 = 128, neuron 2 = 8, epoch = 50
# MD4 RMSE = 0.25076976139316437
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD5
# input = 30, neuron 1 = 128, neuron 2 = 8, epoch = 50
# MD5 RMSE = 0.2688142048799691
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD6
# input = 365, neuron 1 = 128, neuron 2 = 8, epoch = 50
# MD6 RMSE = 0.27099523013131915
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD7
# input = 7, neuron 1 = 256, neuron 2 = 8, epoch = 50
# MD7 RMSE = 0.25158765709719355
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD8
# input = 30, neuron 1 = 256, neuron 2 = 8, epoch = 50
# MD8 RMSE = 0.2703266798196517
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD9
# input = 365, neuron 1 = 256, neuron 2 = 8, epoch = 50
# MD9 RMSE = 0.2763926140197174
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD10
# input = 7, neuron 1 = 64, neuron 2 = 16, epoch = 50
# MD10 RMSE = 0.25185940629539527
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD11
# input = 30, neuron 1 = 64, neuron 2 = 16, epoch = 50
# MD11 RMSE = 0.2645394468062371
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD12
# input = 365, neuron 1 = 64, neuron 2 = 16, epoch = 50
# MD12 RMSE = 0.28434018298158426
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD13
# input = 7, neuron 1 = 128, neuron 2 = 16, epoch = 50
# MD13 RMSE = 0.2510023018639588
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD14
# input = 30, neuron 1 = 128, neuron 2 = 16, epoch = 50
# MD14 RMSE = 0.27118046529283424
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD15
# input = 365, neuron 1 = 128, neuron 2 = 16, epoch = 50
# MD15 RMSE = 0.2734242940785482
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD16
# input = 7, neuron 1 = 256, neuron 2 = 16, epoch = 50
# MD16 RMSE = 0.25230778885743443
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD17
# input = 30, neuron 1 = 256, neuron 2 = 16, epoch = 50
# MD17 RMSE = 0.27785600486984907
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD18
# input = 365, neuron 1 = 256, neuron 2 = 16, epoch = 50
# MD18 RMSE = 0.2713445258810505
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD19
# input = 7, neuron 1 = 64, neuron 2 = 32, epoch = 50
# MD19 RMSE = 0.2521996828135418
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD20
# input = 30, neuron 1 = 64, neuron 2 = 32, epoch = 50
# MD20 RMSE = 0.26676163846907125
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD21
# input = 365, neuron 1 = 64, neuron 2 = 32, epoch = 50
# MD21 RMSE = 0.2812189873141147
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD22
# input = 7, neuron 1 = 128, neuron 2 = 32, epoch = 50
# MD22 RMSE = 0.2517250756403856
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD23
# input = 30, neuron 1 = 128, neuron 2 = 32, epoch = 50
# MD23 RMSE = 0.2745561193645771
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD24
# input = 365, neuron 1 = 128, neuron 2 = 32, epoch = 50
# MD24 RMSE = 0.28247374870627184
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD25
# input = 7, neuron 1 = 256, neuron 2 = 32, epoch = 50
# MD25 RMSE = 0.25116225150674976
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD26
# input = 30, neuron 1 = 256, neuron 2 = 32, epoch = 50
# MD26 RMSE = 0.28259888492638563
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD27
# input = 365, neuron 1 = 256, neuron 2 = 32, epoch = 50
# MD27 RMSE = 0.27645606087042296
# -------------------------------------------------------------------------------------------

# %%
# print('Eksperimen MD lanjutan')

# window = [7,30,365]
# neuron = [64,128,256]
# neuron2 = [8,16,32]
# epoch = [100]
# md = pandas.read_csv('summary_md.csv', index_col=0)
# no=28
# for i in epoch:
#     for j in neuron2:
#         for k in neuron:
#             for l in window:
#                 nama = "MD{0}".format(no)
#                 start = datetime.now()
#                 rmse = eksperimen(nama, scaler, set_latih, set_uji, n_input = l, n_neuron1 = k, n_neuron2 = j, n_epoch = i)
#                 end = datetime.now()
#                 time = (end-start).total_seconds()
#                 md.loc[no] = [nama,l,k,j,i,rmse, time]
#                 md.to_csv('summary_md_lanjutan.csv')
#                 no += 1
# Out:
# Eksperimen MD lanjutan
# Hyperparameter MD28
# input = 7, neuron 1 = 64, neuron 2 = 8, epoch = 100
# MD28 RMSE = 0.25077362479195775
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD29
# input = 30, neuron 1 = 64, neuron 2 = 8, epoch = 100
# MD29 RMSE = 0.28903771378269205
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD30
# input = 365, neuron 1 = 64, neuron 2 = 8, epoch = 100
# MD30 RMSE = 0.2826160364976591
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD31
# input = 7, neuron 1 = 128, neuron 2 = 8, epoch = 100
# MD31 RMSE = 0.25320544069158407
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD32
# input = 30, neuron 1 = 128, neuron 2 = 8, epoch = 100
# MD32 RMSE = 0.3042406219894604
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD33
# input = 365, neuron 1 = 128, neuron 2 = 8, epoch = 100
# MD33 RMSE = 0.276194751957743
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD34
# input = 7, neuron 1 = 256, neuron 2 = 8, epoch = 100
# MD34 RMSE = 0.250424061487299
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD35
# input = 30, neuron 1 = 256, neuron 2 = 8, epoch = 100
# MD35 RMSE = 0.31131125692577877
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD36
# input = 365, neuron 1 = 256, neuron 2 = 8, epoch = 100
# MD36 RMSE = 0.2699430302010076
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD37
# input = 7, neuron 1 = 64, neuron 2 = 16, epoch = 100
# MD37 RMSE = 0.25156574166871487
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD38
# input = 30, neuron 1 = 64, neuron 2 = 16, epoch = 100
# MD38 RMSE = 0.2939016972118687
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD39
# input = 365, neuron 1 = 64, neuron 2 = 16, epoch = 100
# MD39 RMSE = 0.2733724369218078
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD40
# input = 7, neuron 1 = 128, neuron 2 = 16, epoch = 100
# MD40 RMSE = 0.252034613634025
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD41
# input = 30, neuron 1 = 128, neuron 2 = 16, epoch = 100
# MD41 RMSE = 0.3154380281526783
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD42
# input = 365, neuron 1 = 128, neuron 2 = 16, epoch = 100
# MD42 RMSE = 0.27147677062603087
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD43
# input = 7, neuron 1 = 256, neuron 2 = 16, epoch = 100
# MD43 RMSE = 0.2495411057260397
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD44
# input = 30, neuron 1 = 256, neuron 2 = 16, epoch = 100
# MD44 RMSE = 0.32277121006066856
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD45
# input = 365, neuron 1 = 256, neuron 2 = 16, epoch = 100
# MD45 RMSE = 0.26565073579597737
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD46
# input = 7, neuron 1 = 64, neuron 2 = 32, epoch = 100
# MD46 RMSE = 0.2507843546071959
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD47
# input = 30, neuron 1 = 64, neuron 2 = 32, epoch = 100
# MD47 RMSE = 0.2984190787582921
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD48
# input = 365, neuron 1 = 64, neuron 2 = 32, epoch = 100
# MD48 RMSE = 0.27552149119619607
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD49
# input = 7, neuron 1 = 128, neuron 2 = 32, epoch = 100
# MD49 RMSE = 0.25064539750368076
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD50
# input = 30, neuron 1 = 128, neuron 2 = 32, epoch = 100
# MD50 RMSE = 0.30479020390804695
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD51
# input = 365, neuron 1 = 128, neuron 2 = 32, epoch = 100
# MD51 RMSE = 0.2749884746225843
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD52
# input = 7, neuron 1 = 256, neuron 2 = 32, epoch = 100
# MD52 RMSE = 0.2496365846193216
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD53
# input = 30, neuron 1 = 256, neuron 2 = 32, epoch = 100
# MD53 RMSE = 0.3345969491883992
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD54
# input = 365, neuron 1 = 256, neuron 2 = 32, epoch = 100
# MD54 RMSE = 0.26974990317733033
# -------------------------------------------------------------------------------------------

# %%
# print('Eksperimen MD lanjutan2')

# window = [7,30,365]
# neuron = [64,128,256]
# neuron2 = [8,16,32]
# epoch = [200]
# md = pandas.read_csv('summary_md_lanjutan.csv', index_col=0)
# no=55
# for i in epoch:
#     for j in neuron2:
#         for k in neuron:
#             for l in window:
#                 nama = "MD{0}".format(no)
#                 start = datetime.now()
#                 rmse = eksperimen(nama, scaler, set_latih, set_uji, n_input = l, n_neuron1 = k, n_neuron2 = j, n_epoch = i)
#                 end = datetime.now()
#                 time = (end-start).total_seconds()
#                 md.loc[no] = [nama,l,k,j,i,rmse, time]
#                 md.to_csv('summary_md_lanjutan2.csv')
#                 no += 1
# Out:
# Eksperimen MD lanjutan2
# Hyperparameter MD55
# input = 7, neuron 1 = 64, neuron 2 = 8, epoch = 200
# MD55 RMSE = 0.250027674888871
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD56
# input = 30, neuron 1 = 64, neuron 2 = 8, epoch = 200
# MD56 RMSE = 0.3507353457327135
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD57
# input = 365, neuron 1 = 64, neuron 2 = 8, epoch = 200
# MD57 RMSE = 0.27694581811194385
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD58
# input = 7, neuron 1 = 128, neuron 2 = 8, epoch = 200
# MD58 RMSE = 0.2527391291819325
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD59
# input = 30, neuron 1 = 128, neuron 2 = 8, epoch = 200
# MD59 RMSE = 0.35302342886562454
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD60
# input = 365, neuron 1 = 128, neuron 2 = 8, epoch = 200
# MD60 RMSE = 0.2661927764137255
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD61
# input = 7, neuron 1 = 256, neuron 2 = 8, epoch = 200
# MD61 RMSE = 0.2573024033494269
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD62
# input = 30, neuron 1 = 256, neuron 2 = 8, epoch = 200
# MD62 RMSE = 0.3580873261980224
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD63
# input = 365, neuron 1 = 256, neuron 2 = 8, epoch = 200
# MD63 RMSE = 0.2617298314488893
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD64
# input = 7, neuron 1 = 64, neuron 2 = 16, epoch = 200
# MD64 RMSE = 0.25054760789768454
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD65
# input = 30, neuron 1 = 64, neuron 2 = 16, epoch = 200
# MD65 RMSE = 0.3360657141537516
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD66
# input = 365, neuron 1 = 64, neuron 2 = 16, epoch = 200
# MD66 RMSE = 0.2704495711601132
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD67
# input = 7, neuron 1 = 128, neuron 2 = 16, epoch = 200
# MD67 RMSE = 0.25327042162315727
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD68
# input = 30, neuron 1 = 128, neuron 2 = 16, epoch = 200
# MD68 RMSE = 0.3603849285141268
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD69
# input = 365, neuron 1 = 128, neuron 2 = 16, epoch = 200
# MD69 RMSE = 0.2640176377999212
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD70
# input = 7, neuron 1 = 256, neuron 2 = 16, epoch = 200
# MD70 RMSE = 0.25463320770722353
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD71
# input = 30, neuron 1 = 256, neuron 2 = 16, epoch = 200
# MD71 RMSE = 0.3734993859168586
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD72
# input = 365, neuron 1 = 256, neuron 2 = 16, epoch = 200
# MD72 RMSE = 0.26668692830247864
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD73
# input = 7, neuron 1 = 64, neuron 2 = 32, epoch = 200
# MD73 RMSE = 0.25351493639550515
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD74
# input = 30, neuron 1 = 64, neuron 2 = 32, epoch = 200
# MD74 RMSE = 0.3416297219694282
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD75
# input = 365, neuron 1 = 64, neuron 2 = 32, epoch = 200
# MD75 RMSE = 0.2686909193859465
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD76
# input = 7, neuron 1 = 128, neuron 2 = 32, epoch = 200
# MD76 RMSE = 0.2553912345248615
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD77
# input = 30, neuron 1 = 128, neuron 2 = 32, epoch = 200
# MD77 RMSE = 0.3920509877561963
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD78
# input = 365, neuron 1 = 128, neuron 2 = 32, epoch = 200
# MD78 RMSE = 0.27201916842196666
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD79
# input = 7, neuron 1 = 256, neuron 2 = 32, epoch = 200
# MD79 RMSE = 0.2592726110412126
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD80
# input = 30, neuron 1 = 256, neuron 2 = 32, epoch = 200
# MD80 RMSE = 0.37200259071086955
# -------------------------------------------------------------------------------------------
#
# Hyperparameter MD81
# input = 365, neuron 1 = 256, neuron 2 = 32, epoch = 200
# MD81 RMSE = 0.2733382003400581
# -------------------------------------------------------------------------------------------

# %%
summary = pandas.read_csv('summary_md_lanjutan2.csv', index_col=0)

# %%
str(timedelta(seconds=sum(summary['time (s)'].values)))
# Out:
# '1:06:52.298260'

# %%
summary.sort_values('rmse')[0:10]
# Out:
#     nama  input  neuron1  neuron2  epoch      rmse   time (s)
# 43  MD43      7      256       16    100  0.249541  52.609898
# 52  MD52      7      256       32    100  0.249637  64.049808
# 55  MD55      7       64        8    200  0.250028  55.141137
# 34  MD34      7      256        8    100  0.250424  50.296865
# 64  MD64      7       64       16    200  0.250548  56.777742
# 49  MD49      7      128       32    100  0.250645  38.567066
# 1    MD1      7       64        8     50  0.250665  18.161709
# 4    MD4      7      128        8     50  0.250770  18.781562
# 28  MD28      7       64        8    100  0.250774  31.158034
# 46  MD46      7       64       32    100  0.250784  34.799064

# %%
round(0.250301-0.249541, 6)
# Out:
# 0.00076

# %%
# Out:
# array([ 0.46131805,  0.40687679,  0.50143266,  0.04011461, -0.10028653,
#         0.31805158])
